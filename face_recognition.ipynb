# %%
import cv2 
from matplotlib import pyplot as plt 

import numpy as np 
import os

# %%
from PIL import Image

# %%
img = cv2.imread("dhoni_2.jpeg")

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
image = Image.open("dhoni_2.jpeg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x180>

# %%
face_detector = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
def detect_faces(img):
    faces = face_detector.detectMultiScale(img, scaleFactor = 1.1, minNeighbors = 5, minSize = (30,30)) 
    return faces

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap = 'gray')

# %%
faces = detect_faces(gray)

# %%
faces
# Out:
# array([[41, 59, 78, 78]])

# %%
for face in faces:
    (x,y,w,h) = face
    cv2.rectangle(img_rgb, (x,y), (x+w, y+h), (0,255,0), 2) 
    
plt.imshow(img_rgb)
